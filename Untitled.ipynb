# %%
import pandas as pd

d = pd.read_csv('/Users/gyanarora/Downloads/loans-2024-12-04.csv')
d.head()
# Out:
#    GD Id  Application Date                            Customer Name  \
# 0  25912  04 November 2024                         ABHISHEK CHANDEL
# 1  25919  04 November 2024  Mahendar Singh Satvendar Singh Pothiwal
# 2  25920  04 November 2024                             Kunal Rajput
# 3  25931  05 November 2024                     Siddhant Khorjuvekar
# 4  25955  06 November 2024                              JOHN SAMUEL
#
#                               Email  Phone Number      R.M. Name  \
# 0           abhichandel64@gmail.com    7011851286      Ayan Raza
# 1       mahendar0808singh@gmail.com    9980665708      Ayan Raza
# 2              krajput950@gmail.com    9910985835  Mohit Dhingra
# 3  siddhantkhorjuvekar.sk@gmail.com    8208732965      Ayan Raza
# 4              johnsam968@gmail.com    8939156689      Ayan Raza
#
#                    R.M. Email  R.M. Mobile Number      Program Name  \
# 0      ayan.raza@gyandhan.com          9289682987  DS Certification
# ...

# %%
d = pd.read_excel('/Users/gyanarora/Downloads/ES_all_2024-11-01_2024-12-04.xlsx')
d.shape
# Out:
# (132, 54)

# %%
d.head()
# Out:
#              Create Date     Order Id  Mobile number Customer name  \
# 0  2024-12-03 14:52:56.0      E1XHQBR     9867839751  MOHAN  KUMAR
# 1  2024-11-30 21:17:51.0      E1XMLR9     8527462817  Rajat  Kumar
# 2  2024-11-30 20:33:42.0  E1XMLR9-exp     8527462817  Rajat  Kumar
# 3  2024-11-30 19:34:01.0      E1XKPFT     7797281169   MANJU  GAIN
# 4  2024-11-30 19:33:47.0      E1XL53O     9711080596   Vishan  Dev
#
#   Chance of approval Tentative limit Order Amount Detailed status  \
# 0               Good     1,90,000.00  1,90,000.00  Disbursed loan
# 1          Very High     1,70,000.00  1,70,000.00  Disbursed loan
# 2          Very High     1,70,000.00  1,70,000.00  Disbursed loan
# 3          Very High     1,60,000.00  1,60,000.00  Disbursed loan
# 4               Good     1,90,000.00  1,90,000.00  Disbursed loan
#
#    Available limit  Customer Id  ...                  Applicant Email  \
# 0           2601.0   1458644294  ...          himanshuth878@gmail.com
# ...

# %%
pd.to_datetime(d['Create Date']).describe()
# Out:
# count                              132
# mean     2024-11-22 03:36:31.621212160
# min                2024-10-08 16:39:04
# 25%      2024-11-16 14:16:37.249999872
# 50%         2024-11-25 12:41:27.500000
# 75%         2024-11-28 20:22:57.500000
# max                2024-12-03 14:52:56
# Name: Create Date, dtype: object

# %%
d['Mobile number'].nunique()
# Out:
# 84

# %%
d['Chance of approval'].value_counts(normalize=True)
# Out:
# Chance of approval
# Good               0.696970
# Very High          0.227273
# Can not Approve    0.075758
# Name: proportion, dtype: float64

# %%
d['Detailed status'].value_counts(normalize=True)
# Out:
# Detailed status
# Disbursed loan                           0.689394
# Rejected                                 0.106061
# 6) Bank statement required               0.090909
# 1) Ready to disburse                     0.068182
# 4) KYC Pending                           0.022727
# 6.1) Bank statement/document required    0.015152
# 4.1) Better KYC images required          0.007576
# Name: proportion, dtype: float64
